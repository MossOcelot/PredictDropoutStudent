# %%
import pandas 

df = pandas.read_excel("data/data_dropout_59-64.xlsx")

df
# Out:
#       STUDENT_ID  ADMIT_YEAR  ADMIT_TERM  MAJOR_ID  \
# 0     Y6rAL6a3ug      2559.0         1.0     215.0
# 1     ihEYqG7Q2P      2559.0         1.0     225.0
# 2     EJwFAHDeDB      2559.0         1.0     210.0
# 3     mAN7tIZz44      2559.0         1.0     215.0
# 4     rWseDSww8R      2559.0         1.0     235.0
# ...          ...         ...         ...       ...
# 4116  IY8jWx00mt      2564.0         1.0     226.0
# 4117  uVfxDYkac8      2564.0         1.0     203.0
# 4118  IcXALKhfPP      2564.0         1.0     203.0
# 4119  q5SWpcypnh      2564.0         1.0     203.0
# 4120         NaN         NaN         NaN       NaN
#
#                    MAJOR_NAME_THAI  DEPT_ID                    DEPT_NAME_THAI  \
# 0                วิศวกรรมเครื่องกล     30.0          ภาควิชาวิศวกรรมเครื่องกล
# 1                วิศวกรรมอุตสาหการ     31.0          ภาควิชาวิศวกรรมอุตสาหการ
# 2                    วิศวกรรมไฟฟ้า     28.0              ภาควิชาวิศวกรรมไฟฟ้า
# ...

# %%
df['MAJOR_ID'].unique()
# Out:
# array([215., 225., 210., 235., 220., 230., 216., 250., 200., 240., 226.,
#        214., 205., 203., 254., 204.,  nan])

# %%
df['DEGREE_ID'].unique()
# Out:
# array([218., 228., 213., 240., 223., 233., 242., 238.,  nan, 243., 239.,
#        211., 245., 254., 149., 252., 200.])

# %%
df['MAJOR_NAME_THAI'].unique()
# Out:
# array(['วิศวกรรมเครื่องกล', 'วิศวกรรมอุตสาหการ', 'วิศวกรรมไฟฟ้า',
#        'วิศวกรรมเหมืองแร่', 'วิศวกรรมโยธา', 'วิศวกรรมเคมี',
#        'วิศวกรรมเมคาทรอนิกส์', 'วิศวกรรมวัสดุ', 'ยังไม่แยกสาขาวิชา',
#        'วิศวกรรมคอมพิวเตอร์', 'วิศวกรรมการผลิต', 'วิศวกรรมชีวการแพทย์',
#        'วิศวกรรมสิ่งแวดล้อม', 'วิศวกรรมและการจัดการนวัตกรรม',
#        'วิศวกรรมเหมืองแร่และวัสดุ', 'วิศวกรรมปัญญาประดิษฐ์', nan],
#       dtype=object)

# %%
df['COURSE_DEGREE'].unique()
# Out:
# array(['วิศวกรรมศาสตรบัณฑิต (วิศวกรรมเครื่องกล)',
#        'วิศวกรรมศาสตรบัณฑิต (วิศวกรรมอุตสาหการ)',
#        'วิศวกรรมศาสตรบัณฑิต (วิศวกรรมไฟฟ้า)',
#        'วิศวกรรมศาสตรบัณฑิต (วิศวกรรมเหมืองแร่)',
#        'วิศวกรรมศาสตรบัณฑิต (วิศวกรรมโยธา)',
#        'วิศวกรรมศาสตรบัณฑิต (วิศวกรรมเคมี)',
#        'วิศวกรรมศาสตรบัณฑิต (วิศวกรรมเมคาทรอนิกส์)',
#        'วิศวกรรมศาสตรบัณฑิต (วิศวกรรมวัสดุ)', 'รอระบุหลักสูตร',
#        'วิศวกรรมศาสตรบัณฑิต (วิศวกรรมคอมพิวเตอร์)',
#        'วิศวกรรมศาสตรบัณฑิต (วิศวกรรมการผลิต)',
#        'วิศวกรรมศาสตรบัณฑิต (วิศวกรรมชีวการแพทย์)',
#        'วิศวกรรมศาสตรบัณฑิต (วิศวกรรมสิ่งแวดล้อม)',
#        'วิศวกรรมศาสตรบัณฑิต (วิศวกรรมและการจัดการนวัตกรรม)',
#        'วิศวกรรมศาสตรบัณฑิต (วิศวกรรมเหมืองแร่และวัสดุ)',
#        'วิศวกรรมศาสตรบัณฑิต (วิศวกรรมปัญญาประดิษฐ์)',
#        'วิศวกรรมศาสตรบัณฑิต', nan], dtype=object)

# %%
from pycaret.classification import *

# %%
# STUDY_STATUS
experiment = setup(df, target="STUDY_STATUS" )
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[31], line 2
#       1 # STUDY_STATUS
# ----> 2 experiment = setup(df, target="STUDY_STATUS" )
#
# ...

# %%
best_model = compare_models()
best_model
# Out:
#
#
# Initiated  . . . . . . . . . . . . . . . . . .             10:24:36
# Status     . . . . . . . . . . . . . . . . . .     Fitting 10 Folds
# Estimator  . . . . . . . . . . . . . . . . . .  Logistic Regression
# <style type="text/css">
# #T_e312f th {
#   text-align: left;
# }
# ...

# %%
predictions = predict_model(best_model, data=data_test)

# %%
data = ['ตรัง', 'ตรัง', 5, 'วิทยาเขตหาดใหญ่', 'วิศวกรรมเครื่องกล', 'ภาควิชาวิศวกรรมเครื่องกล', 3.1, 3.2, 'ยังไม่มี', 'ยังไม่มี', 'ยังไม่มี', 'ยังไม่มี', 'ยังไม่มี', 'ยังไม่มี']
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 model = load_model('model/model_top_no_STILL_STUDENT_2Class_map_E_to_R_last_final.pkl')
#       2 model.feature_names_in_
#
# File ~/Desktop/งานมหาลัย/Project/DropOut/venv/lib/python3.10/site-packages/pycaret/classification/functional.py:2468, in load_model(model_name, platform, authentication, verbose)
#    2465 if experiment is None:
#    2466     experiment = _EXPERIMENT_CLASS()
# -> 2468 return experiment.load_model(
#    2469     model_name=model_name,
#    2470     platform=platform,
#    2471     authentication=authentication,
#    2472     verbose=verbose,
#    2473 )
#
# File ~/Desktop/งานมหาลัย/Project/DropOut/venv/lib/python3.10/site-packages/pycaret/classification/oop.py:3106, in ClassificationExperiment.load_model(self, model_name, platform, authentication, verbose)
# ...
