# %%
import pandas 

df = pandas.read_excel("data/data_dropout_59-64.xlsx")

df
# Out:
#       STUDENT_ID  ADMIT_YEAR  ADMIT_TERM  MAJOR_ID  \
# 0     Y6rAL6a3ug      2559.0         1.0     215.0
# 1     ihEYqG7Q2P      2559.0         1.0     225.0
# 2     EJwFAHDeDB      2559.0         1.0     210.0
# 3     mAN7tIZz44      2559.0         1.0     215.0
# 4     rWseDSww8R      2559.0         1.0     235.0
# ...          ...         ...         ...       ...
# 4116  IY8jWx00mt      2564.0         1.0     226.0
# 4117  uVfxDYkac8      2564.0         1.0     203.0
# 4118  IcXALKhfPP      2564.0         1.0     203.0
# 4119  q5SWpcypnh      2564.0         1.0     203.0
# 4120         NaN         NaN         NaN       NaN
#
#                    MAJOR_NAME_THAI  DEPT_ID                    DEPT_NAME_THAI  \
# 0                วิศวกรรมเครื่องกล     30.0          ภาควิชาวิศวกรรมเครื่องกล
# 1                วิศวกรรมอุตสาหการ     31.0          ภาควิชาวิศวกรรมอุตสาหการ
# 2                    วิศวกรรมไฟฟ้า     28.0              ภาควิชาวิศวกรรมไฟฟ้า
# 3                วิศวกรรมเครื่องกล     30.0          ภาควิชาวิศวกรรมเครื่องกล
# 4                วิศวกรรมเหมืองแร่     33.0  ภาควิชาวิศวกรรมเหมืองแร่และวัสดุ
# ...                            ...      ...                               ...
# 4116               วิศวกรรมการผลิต     31.0          ภาควิชาวิศวกรรมอุตสาหการ
# 4117  วิศวกรรมและการจัดการนวัตกรรม    193.0                 คณะวิศวกรรมศาสตร์
# 4118  วิศวกรรมและการจัดการนวัตกรรม    193.0                 คณะวิศวกรรมศาสตร์
# 4119  วิศวกรรมและการจัดการนวัตกรรม    193.0                 คณะวิศวกรรมศาสตร์
# 4120                           NaN      NaN                               NaN
#
#       FAC_ID      FAC_NAME_THAI  STUDY_LEVEL_ID  ... เกรดปี4เทอม1  \
# 0        6.0  คณะวิศวกรรมศาสตร์             6.0  ...          NaN
# 1        6.0  คณะวิศวกรรมศาสตร์             6.0  ...         3.83
# 2        6.0  คณะวิศวกรรมศาสตร์             6.0  ...          NaN
# 3        6.0  คณะวิศวกรรมศาสตร์             6.0  ...         3.73
# 4        6.0  คณะวิศวกรรมศาสตร์             6.0  ...         1.22
# ...      ...                ...             ...  ...          ...
# 4116     6.0  คณะวิศวกรรมศาสตร์             6.0  ...          NaN
# 4117     6.0  คณะวิศวกรรมศาสตร์             6.0  ...          NaN
# 4118     6.0  คณะวิศวกรรมศาสตร์             6.0  ...          NaN
# 4119     6.0  คณะวิศวกรรมศาสตร์             6.0  ...          NaN
# 4120     NaN                NaN             NaN  ...          NaN
#
#       เกรดปี4เทอม2 เกรดปี4เทอม3 GPA_SCHOOL     FUND_NAME FUND_NAME_CODE  \
# 0              NaN          NaN       3.10  ไม่ได้รับทุน              N
# 1             4.00          NaN       3.32  ไม่ได้รับทุน              N
# 2              NaN          NaN       3.78     ได้รับทุน              Y
# 3              NaN          NaN       3.77     ได้รับทุน              Y
# 4             0.72          0.0       3.21  ไม่ได้รับทุน              N
# ...            ...          ...        ...           ...            ...
# 4116           NaN          NaN       3.74           NaN          other
# 4117           NaN          NaN       3.25           NaN          other
# 4118           NaN          NaN       2.79           NaN          other
# 4119           NaN          NaN       3.26  ไม่ได้รับทุน              N
# 4120           NaN          NaN        NaN           NaN            NaN
#
#      DEFORMITY_NAME DEFORMITY_NAME_code     PARENTS_MARRIED_NAME  \
# 0          ไม่พิการ                   N              อยู่ด้วยกัน
# 1          ไม่พิการ                   N              อยู่ด้วยกัน
# 2          ไม่พิการ                   N  บิดาและมารดาแต่งงานใหม่
# 3          ไม่พิการ                   N           บิดาถึงแก่กรรม
# 4          ไม่พิการ                   N              อยู่ด้วยกัน
# ...             ...                 ...                      ...
# 4116       ไม่พิการ                   N              อยู่ด้วยกัน
# 4117       ไม่พิการ                   N              อยู่ด้วยกัน
# 4118       ไม่พิการ                   N          มารดาถึงแก่กรรม
# 4119       ไม่พิการ                   N              อยู่ด้วยกัน
# 4120            NaN                 NaN                      NaN
#
#      PARENTS_MARRIED_NAME_CODE
# 0                          9.0
# 1                          9.0
# 2                          4.0
# 3                          6.0
# 4                          9.0
# ...                        ...
# 4116                       9.0
# 4117                       9.0
# 4118                       8.0
# 4119                       9.0
# 4120                       NaN
#
# [4121 rows x 60 columns]

# %%
df['PROVINCE_NAME_THAI'].unique()
# Out:
# array(['ตรัง', 'ระนอง', 'สงขลา', 'ยะลา', 'สตูล', 'สุราษฎร์ธานี', 'ภูเก็ต',
#        'พังงา', 'นครศรีธรรมราช', 'ปัตตานี', 'กระบี่', 'ชุมพร',
#        'กรุงเทพมหานคร', 'พัทลุง', 'นราธิวาส', 'เชียงใหม่', 'สมุทรปราการ',
#        'นนทบุรี', 'นครสวรรค์', 'ประจวบคีรีขันธ์', 'ชัยนาท', 'พะเยา',
#        'นครปฐม', 'นครราชสีมา', 'สุพรรณบุรี', 'สระบุรี', 'ลพบุรี',
#        'สมุทรสาคร', 'เชียงราย', 'พระนครศรีอยุธยา', 'กาญจนบุรี',
#        'ฉะเชิงเทรา', 'เพชรบูรณ์', 'ขอนแก่น', 'ราชบุรี', 'ปราจีนบุรี',
#        'ระยอง', 'กาฬสินธุ์', 'กําแพงเพชร', 'อื่นๆ', 'อุบลราชธานี',
#        'ชัยภูมิ', 'ลำปาง', 'สกลนคร', 'มหาสารคาม', 'แพร่', 'ตาก', 'ลำพูน',
#        'พิษณุโลก', 'พิจิตร', 'สุรินทร์', 'นครพนม', 'อุตรดิตถ์',
#        'ปทุมธานี', 'จันทบุรี', 'หนองบัวลําภู', 'ชลบุรี', 'เลย', 'นครนายก',
#        'หนองคาย', 'สมุทรสงคราม', 'ร้อยเอ็ด', 'อุดรธานี', 'สระแก้ว',
#        'ยโสธร', 'อุทัยธานี', 'เพชรบุรี', 'ตราด', 'กำแพงเพชร', 'อ่างทอง',
#        'สุโขทัย', 'บึงกาฬ', nan], dtype=object)

# %%
n = ["%03d" % (number) for number in df['DEPT_ID'].unique()[:-1]]
import numpy 
numpy.array(n)
# Out:
# array(['030', '031', '028', '033', '029', '032', '193', '034'],
#       dtype='<U3')

# %%
df['MAJOR_ID'].unique()
# Out:
# array([215., 225., 210., 235., 220., 230., 216., 250., 200., 240., 226.,
#        214., 205., 203., 254., 204.,  nan])

# %%
from pycaret.classification import *

# %%
# STUDY_STATUS
experiment = setup(df, target="STUDY_STATUS" )

# %%
best_model = compare_models()
best_model
# Out:
#
#
# Initiated  . . . . . . . . . . . . . . . . . .             10:24:36
# Status     . . . . . . . . . . . . . . . . . .     Fitting 10 Folds
# Estimator  . . . . . . . . . . . . . . . . . .  